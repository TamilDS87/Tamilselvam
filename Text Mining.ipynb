# %%
import pandas as pd
import numpy as np
import tweepy
import re 
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
wordnet = WordNetLemmatizer()
import re
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
import requests
from bs4 import BeautifulSoup as bs

# %%
samsung_reviews = []

# %%
for i in range (1,31):
    op=[]
    url ="https://www.amazon.in/Samsung-Storage-Snapdragon-sAMOLED-Display/product-reviews/B09CV6FJ62"
    response = requests.get(url)
    soup = bs(response.content, "html.parser")
    reviews = soup.findAll("span", attrs={"class": "a-size-base review-text review-text-content"})
    for i in range(len(reviews)):
         op.append(reviews[i].text)
    samsung_reviews.extend(op)

# %%
##Writing reviews in a text file
with open("samsung.txt","w",encoding = 'utf-8') as output:
    output.write(str(samsung_reviews))

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Appsysm-3\\Downloads\\DS Assignments'

# %%
## Joining all the reviews into single paragraph
sam_rev_string = " ".join(samsung_reviews)

# %%
##Removing unwanted symbols in case present
sam_rev_string = re.sub("[^A-Za-z" "]+"," ",sam_rev_string).lower()
sam_rev_string =re.sub("[0-9" "]+"," ",sam_rev_string)

# %%
##Splitting each word with space -- Tokanization
sam_rev_words = sam_rev_string.split(" ")

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Appsysm-3\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sam_rev_words = [w for w in sam_rev_words if not w in stop_words]

# %%
## Joining all the reviews into single paragraph
sam_rev_string =" ".join(sam_rev_words)

# %%
# WordCloud can be performed on the string inputs. That is the reason we have combined 
# entire reviews into single paragraph
# Simple word cloud

wordcloud_ip = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(sam_rev_string)

# %%
plt.imshow(wordcloud_ip)

# %%
# negative words  Choose path for -ve words stored in system
with open(r'C:\Users\Appsysm-3\Downloads\Negative words.txt', 'r') as file:
    negwords = file.readlines()
negwords = [word.strip() for word in negwords]

# %%
negwords =negwords[37:]

# %%
##Considering only the words which are present in the positive words

sam_pos = " ".join([w for w in sam_rev_words if w in negwords])

# %%
##Building Positive word cloud
wordcloud_pos = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(sam_pos)

plt.imshow(wordcloud_pos)

# %%
##Unique words
sam_unique = list(set(" ".join(samsung_reviews).split(" ")))

# %%
sam_unique
# Out:
# ['',
#  'charge',
#  'F62Samsung',
#  'good.\n',
#  'UI',
#  'great',
#  'perform',
#  'times',
#  'lag-free',
#  'ahead',
#  '(helpful',
#  'colour.Store',
#  'out',
#  'my',
#  '(and',
#  'Quad',
#  'PhotosTriple',
#  'fine',
#  'unused)',
#  'anymore.',
#  'handle',
#  'ProVivo',
#  'until',
#  'At',
#  'Email',
#  'keep',
#  'Blue,',
#  'second',
#  'hold',
#  'ponzi',
#  'SIM',
#  '2,083/monthFor',
#  'single',
#  'fault',
#  'Once',
#  'PPI)120',
#  'user.',
#  'order',
#  'want',
#  '128',
#  'holds',
#  'user',
#  '36,99992%Samsung',
#  'OffersNo',
#  'peripherals',
#  'ROM,',
#  '5GBy',
#  '13',
#  'may',
#  'ICICI',
#  'recomment',
#  'light',
#  'internal',
#  'that.The',
#  'on',
#  'MobilesRealme',
#  'Pro',
#  'does.',
#  'Other',
#  'step.',
#  'well.',
#  "you've",
#  'camera:',
#  'Samsung!Durability:',
#  'store',
#  'Note',
#  'treat',
#  'step',
#  'battery.',
#  'best.',
#  'Following',
#  'moderate',
#  'playtimeKnox',
#  'properly',
#  'root',
# ...
